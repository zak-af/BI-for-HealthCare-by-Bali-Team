# %%
import pandas as pd

# %%
#import data
indeks_ = pd.read_csv('indeks_kesehatan.csv')
keluhan_ = pd.read_csv('keluhan_kesehatan.csv')
ims_ = pd.read_csv('jml_ims.csv')
balita_ = pd.read_csv('jml_balita.csv')

# %%
# copy data
data1 = indeks_.copy()
data2 = keluhan_.copy()
data3 = ims_.copy()
data4 = balita_.copy()

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   54 non-null     int64
#  1   kode_provinsi        54 non-null     int64
#  2   nama_provinsi        54 non-null     object
#  3   kode_kabupaten_kota  54 non-null     int64
#  4   nama_kabupaten_kota  54 non-null     object
#  5   jumlah_balita        54 non-null     int64
#  6   satuan               54 non-null     object
#  7   tahun                54 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 3.5+ KB

# %%
#drop column
data1 = data1.drop(['id','kode_provinsi', 'satuan'], axis=1)
data2 =data2.drop(['id', 'kode_provinsi', 'satuan'], axis=1)
data3 =data3.drop(['id', 'kode_provinsi', 'satuan'], axis=1)
data4 =data4.drop(['id', 'kode_provinsi', 'satuan'], axis=1)

#merge
df = data1.merge(data2, on=('kode_kabupaten_kota', 'nama_provinsi', 'nama_kabupaten_kota', 'tahun'), how='outer')
df = df.merge(data3, on=('kode_kabupaten_kota', 'nama_provinsi', 'nama_kabupaten_kota', 'tahun'), how='outer')
df = df.merge(data4, on=('kode_kabupaten_kota', 'nama_provinsi', 'nama_kabupaten_kota', 'tahun'), how='outer')

# %%
df
# Out:
#     nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  indeks_kesehatan  \
# 0      JAWA BARAT                 3201     KABUPATEN BOGOR             77.43
# 1      JAWA BARAT                 3202  KABUPATEN SUKABUMI             76.10
# 2      JAWA BARAT                 3203   KABUPATEN CIANJUR             75.02
# 3      JAWA BARAT                 3204   KABUPATEN BANDUNG             81.44
# 4      JAWA BARAT                 3205     KABUPATEN GARUT             77.44
# ..            ...                  ...                 ...               ...
# 319    JAWA BARAT                 3275         KOTA BEKASI             84.91
# 320    JAWA BARAT                 3276          KOTA DEPOK             84.03
# 321    JAWA BARAT                 3277         KOTA CIMAHI             83.40
# 322    JAWA BARAT                 3278    KOTA TASIKMALAYA             80.52
# 323    JAWA BARAT                 3279         KOTA BANJAR               NaN
#
# ...

# %%
 #ubah kolomn
df = df[['tahun', 'nama_provinsi', 'kode_kabupaten_kota', 'nama_kabupaten_kota', 'indeks_kesehatan', 'persentase_penduduk', 'jumlah_kasus', 'jumlah_balita']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 324 entries, 0 to 323
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tahun                324 non-null    int64
#  1   nama_provinsi        324 non-null    object
#  2   kode_kabupaten_kota  324 non-null    int64
#  3   nama_kabupaten_kota  324 non-null    object
#  4   indeks_kesehatan     323 non-null    float64
#  5   persentase_penduduk  189 non-null    float64
#  6   jumlah_kasus         54 non-null     float64
#  7   jumlah_balita        54 non-null     float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 22.8+ KB

# %%
# hapus tahun

df1 = df.copy()

clean_tahun = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
df1 = df1[df1.tahun.isin(clean_tahun) == False]

# %%
df1.isna().sum()
# Out:
# tahun                  0
# nama_provinsi          0
# kode_kabupaten_kota    0
# nama_kabupaten_kota    0
# indeks_kesehatan       1
# persentase_penduduk    0
# jumlah_kasus           0
# jumlah_balita          0
# dtype: int64

# %%
#rename colomns
df1.rename(columns = {'jumlah_kasus': 'jml_ims', 'jumlah_balita': 'jml_balita'}, inplace=True)

# %%
df1.isna().sum()
# Out:
# tahun                  0
# nama_provinsi          0
# kode_kabupaten_kota    0
# nama_kabupaten_kota    0
# indeks_kesehatan       0
# persentase_penduduk    0
# jml_ims                0
# jml_balita             0
# dtype: int64

# %%
#fillna kabupaten banjar
df1 = df1.fillna(78.14)

# %%
df1.to_csv('jabar_sehat20_21.csv')

# %%
data = pd.read_csv('jabar_sehat20_21.csv')

# %%
data.to_csv('jabar_sehat20_21.csv')

# %%
data['tahun'].unique()
# Out:
# array([2020, 2021])

# %%
data
# Out:
#     tahun nama_provinsi  kode_kabupaten_kota      nama_kabupaten_kota  \
# 0    2020    JAWA BARAT                 3201          KABUPATEN BOGOR
# 1    2020    JAWA BARAT                 3202       KABUPATEN SUKABUMI
# 2    2020    JAWA BARAT                 3203        KABUPATEN CIANJUR
# 3    2020    JAWA BARAT                 3204        KABUPATEN BANDUNG
# 4    2020    JAWA BARAT                 3205          KABUPATEN GARUT
# 5    2020    JAWA BARAT                 3206    KABUPATEN TASIKMALAYA
# 6    2020    JAWA BARAT                 3207         KABUPATEN CIAMIS
# 7    2020    JAWA BARAT                 3208       KABUPATEN KUNINGAN
# 8    2020    JAWA BARAT                 3209        KABUPATEN CIREBON
# 9    2020    JAWA BARAT                 3210     KABUPATEN MAJALENGKA
# 10   2020    JAWA BARAT                 3211       KABUPATEN SUMEDANG
# 11   2020    JAWA BARAT                 3212      KABUPATEN INDRAMAYU
# ...
