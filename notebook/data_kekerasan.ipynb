# %%
import pandas as pd

# %%
#data_awal
data1 = pd.read_csv('datalab/kdrt_bedasarkan_jk_.csv')
data2 = pd.read_csv('datalab/kekerasan_berdasarkan_kelompok_usia.csv')
data3 = pd.read_csv('datalab/kekerasan_berdasarkan_tingkat_pendidikan.csv')

#copy data
df1 = data1.copy()
df2 = data2.copy()
df3 = data3.copy()

#drop column
df1 = df1.drop(['id', 'kode_provinsi', 'satuan'], axis=1)
df2 = df2.drop(['id', 'kode_provinsi', 'satuan'], axis=1)
df3 = df3.drop(['id', 'kode_provinsi', 'satuan'], axis=1)


#rename columns
df1.rename(columns = {'jumlah_korban': 'jml_kdrt'}, inplace=True)
df2.rename(columns = {'jumlah_korban': 'jml_kelompok_usia'}, inplace=True)
df3.rename(columns = {'jumlah': 'jml_kelompok_pendidikan'}, inplace=True)

#mengurutkan columns
df1 = df1[['tahun', 'nama_provinsi', 'kode_kabupaten_kota', 'nama_kabupaten_kota', 'jenis_kelamin', 'jml_kdrt']]
df2 = df2[['tahun', 'nama_provinsi', 'kode_kabupaten_kota', 'nama_kabupaten_kota', 'jenis_kelamin', 'kategori_usia', 'jml_kelompok_usia']]
df3 = df3[['tahun', 'nama_provinsi', 'kode_kabupaten_kota', 'nama_kabupaten_kota', 'jenis_kelamin', 'kategori_pendidikan', 'jml_kelompok_pendidikan']]

# %%
df2.to_csv('kdrt_2018_2021.csv')
df3.to_csv('kekerasan_usia_2018_2021.csv')
df4.to_csv('kekerasan_pendidikan_2018_2021.csv')

# %%
data1 = pd.read_csv('kdrt_2018_2021.csv')
data2 = pd.read_csv('kekerasan_usia_2018_2021.csv')
data3 = pd.read_csv('kekerasan_pendidikan_2018_2021.csv')

# %%
#wrangling data3 (kekerasan berdasarkan kategori pendidikan)
df3.isna().sum()
# Out:
# tahun                        0
# nama_provinsi                0
# kode_kabupaten_kota          0
# nama_kabupaten_kota          0
# jenis_kelamin                0
# kategori_pendidikan        108
# jml_kelompok_pendidikan      0
# dtype: int64

# %%
df3
# Out:
#      tahun nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0     2018    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1     2018    JAWA BARAT                 3201     KABUPATEN BOGOR
# 2     2018    JAWA BARAT                 3201     KABUPATEN BOGOR
# 3     2018    JAWA BARAT                 3201     KABUPATEN BOGOR
# 4     2018    JAWA BARAT                 3201     KABUPATEN BOGOR
# ..     ...           ...                  ...                 ...
# 859   2021    JAWA BARAT                 3279         KOTA BANJAR
# 860   2021    JAWA BARAT                 3279         KOTA BANJAR
# 861   2021    JAWA BARAT                 3279         KOTA BANJAR
# 862   2021    JAWA BARAT                 3279         KOTA BANJAR
# 863   2021    JAWA BARAT                 3279         KOTA BANJAR
#
#     jenis_kelamin kategori_pendidikan  jml_kelompok_pendidikan
# 0       LAKI-LAKI                 NaN                        0
# ...

# %%
# menyesuaikan columns data 3
kategori = {'TIDAK \nSEKOLAH': 'TIDAK SEKOLAH','PERGURUAN \nTINGGI': 'PERGURUAN TINGGI'}
df3 = df3.replace({'kategori_pendidikan': kategori})
df3.head(5)
# Out:
#    tahun nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota jenis_kelamin  \
# 0   2018    JAWA BARAT                 3201     KABUPATEN BOGOR     LAKI-LAKI
# 1   2018    JAWA BARAT                 3201     KABUPATEN BOGOR     LAKI-LAKI
# 2   2018    JAWA BARAT                 3201     KABUPATEN BOGOR     LAKI-LAKI
# 3   2018    JAWA BARAT                 3201     KABUPATEN BOGOR     LAKI-LAKI
# 4   2018    JAWA BARAT                 3201     KABUPATEN BOGOR     LAKI-LAKI
#
#   kategori_pendidikan  jml_kelompok_pendidikan
# 0                 NaN                        0
# 1       TIDAK SEKOLAH                        0
# 2                  SD                        0
# 3                SLTP                        0
# 4                SLTA                        0

# %%
#dropna data3
df3 = df3.dropna(inplace=True)
df3_ = df3.copy()

# %%
df3_
# Out:
#      tahun nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 1     2018    JAWA BARAT                 3201     KABUPATEN BOGOR
# 2     2018    JAWA BARAT                 3201     KABUPATEN BOGOR
# 3     2018    JAWA BARAT                 3201     KABUPATEN BOGOR
# 4     2018    JAWA BARAT                 3201     KABUPATEN BOGOR
# 5     2018    JAWA BARAT                 3201     KABUPATEN BOGOR
# ..     ...           ...                  ...                 ...
# 859   2021    JAWA BARAT                 3279         KOTA BANJAR
# 860   2021    JAWA BARAT                 3279         KOTA BANJAR
# 861   2021    JAWA BARAT                 3279         KOTA BANJAR
# 862   2021    JAWA BARAT                 3279         KOTA BANJAR
# 863   2021    JAWA BARAT                 3279         KOTA BANJAR
#
#     jenis_kelamin kategori_pendidikan  jml_kelompok_pendidikan
# 1       LAKI-LAKI       TIDAK SEKOLAH                        0
# ...

# %%
#groupby kategori 
count_pendidikan = df3_.groupby(['kategori_pendidikan'])[['jml_kelompok_pendidikan']].sum()
count_pendidikan
# Out:
#                      jml_kelompok_pendidikan
# kategori_pendidikan
# PAUD                                       3
# PERGURUAN TINGGI                          78
# SD                                       181
# SLTA                                     237
# SLTP                                     182
# TIDAK SEKOLAH                             40
# TK                                        13

# %%
#export data olahan:
df1.to_csv('kdrt_2018_2021.csv')
df2.to_csv('kekerasan_usia_2018_2021.csv')
df3_.to_csv('kekerasan_pendidikan_2018_2021.csv')

# %%
df1.info()
df2.info()
df3_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tahun                108 non-null    int64
#  1   nama_provinsi        108 non-null    object
#  2   kode_kabupaten_kota  108 non-null    int64
#  3   nama_kabupaten_kota  108 non-null    object
#  4   jenis_kelamin        108 non-null    object
#  5   jml_kdrt             108 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 5.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tahun                756 non-null    int64
#  1   nama_provinsi        756 non-null    object
#  2   kode_kabupaten_kota  756 non-null    int64
#  3   nama_kabupaten_kota  756 non-null    object
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   108 non-null    int64
#  1   kode_provinsi        108 non-null    int64
#  2   nama_provinsi        108 non-null    object
#  3   kode_kabupaten_kota  108 non-null    int64
#  4   nama_kabupaten_kota  108 non-null    object
#  5   jenis_kelamin        108 non-null    object
#  6   jumlah_korban        108 non-null    int64
#  7   satuan               108 non-null    object
#  8   tahun                108 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 7.7+ KB
